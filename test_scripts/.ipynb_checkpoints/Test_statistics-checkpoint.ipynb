# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sc
from scipy.stats import norm, beta


import sys
sys.path.insert(0, '../lib')
sys.path.insert(0, '../src')


import ml_estimation as ml
import ml_estimation2 as ml2
import model1_plots as mp
import model1_explore as me
import model2_explore as me2
import Utilities as util
import test_stat as ts

# %% [markdown]
# In this note book we will show and develop the calculations of the test statistics. Based on a sample and a fit from a beta mixture the statistics will be calculated.

# %%
## draw sample
# make data set
N = 100

def drawMixBeta(N, alpha1, beta1, alpha2, beta2, p, seed = False):
    if seed:
        np.random.seed(0)
    x = np.random.rand(N)
    y1 = beta.rvs(alpha1, beta1, size = N)
    y2 = beta.rvs(alpha2, beta2, size = N)
    u  = (x < p)
    return u * y1 + ~u * y2

params = (2, 7, 5, .9, .7)
x = drawMixBeta(N, *params, seed = True)

est = me.fitMixBetaCTH(x * 16e3)
est2 = me2.fitMixBetaCTH(x * 16e3)

# %%
est2.params
params2 = est2.params
ml2.mnToAb(*params2[:2]), est.params[:2]

# est.params, est2.params
# Out:
# ((2.1092367541401127, 6.749571503989973), array([2.10923962, 6.7495817 ]))

# %%
plt.hist(ml.UnitInttoCTH(x)*1e-3, bins = 50, density = True)
mp.plotCTHBetaMix(plt, *est.params)
# plt.ylim([0, 2])
est.params, params
# mp.plotCTHBetaMix(plt, *est.params)
mp.plotCTHBetaMix(plt, *params, plotSubBeta = False, maincolor = 'grey', mainlabel = 'true')

params2 = np.zeros(5)
params2[:2] = ml2.mnToAb(*est2.params[:2])
params2[2:4] = ml2.mnToAb(*est2.params[2:4])
params2[4] = est2.params[4]

# mp.plotCTHBetaMix(plt, *params2, plotSubBeta = True, maincolor = 'blue', mainlabel = 'est2')
mp.plotCTHBetaMix(plt, *est2.params, plotSubBeta = True, maincolor = 'blue', mainlabel = 'est2', param='mean_sum')


params2, est.params
# Out:
# (array([ 2.10923675,  6.7495715 , 10.8177394 ,  1.61519679,  0.812427  ]),
#  array([ 2.10923962,  6.7495817 , 10.81765358,  1.61518648,  0.81242737]))

# %%
mp.plotCTHBetaMix(plt, *params, plotSubBeta = True, maincolor = 'blue', mainlabel = 'est2')
params2, params
# Out:
# (array([ 2.10923675,  6.7495715 , 10.8177394 ,  1.61519679,  0.812427  ]),
#  (2, 7, 5, 0.9, 0.7))

# %% [markdown]
# How well is this fit?

# %%
k = 5 # mixture of two beta
AIC = ts.AIC(5, est.llf )
BIC = ts.BIC(5, est.llf, N)
print('AIC = ', AIC)
print('BIC = ', BIC)
# Out:
# AIC =  -48.05720832874849
# BIC =  -35.03135739880803

# %% [markdown]
# ### Kolmogorov Smirnov

# %%
KS = ts.KS(x, ml.cdf_bmix, args = (est.params[:]))
KS
# Out:
# KstestResult(statistic=0.04195217630708495, pvalue=0.9915783354073694)

# %% [markdown]
# ### Cramer von Mises

# %%
CM = ts.CM(x, ml.cdf_bmix, args = (est.params[:]))
CM
# Out:
# CramerVonMisesResult(statistic=0.021524655437393677, pvalue=0.9955340178710926)

# %% [markdown]
# ### Anderson Darling

# %%
def AD(x, F_cdf, *args):
    y = np.sort(x)
    cdf = F_cdf(y, *args)
    logcdf = np.log(cdf)
    logsf = np.log(1 - cdf)

    i = np.arange(1, N + 1)
    A2 = -N - np.sum((2*i - 1.0) / N * (logcdf + logsf[::-1]), axis=0)

    return A2

AD(x, ml.cdf_bmix, *est.params)
# Out:
# 0.152629040711048
