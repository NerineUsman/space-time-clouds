# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace( 0 , 1, 51 )
y = np.linspace( 0, 1, 51)
X, Y  = np.meshgrid(x, y)
X, Y = X.flatten(), Y.flatten()
hue_c = .9
rgb_cycle = np.vstack((            # Three sinusoids
    (Y >= X) * 1 +  (Y < X) * (Y - X + 1) + ((X + Y) > 1) * -(X + Y -1) * hue_c, # scaled to [0,1]
    ((X + Y) < 1) * ( -X - Y + 1) * hue_c  , # 120° phase shifted.
    (Y >= X) * (X - Y + 1) +  (Y < X) * 1 + ((X + Y) > 1) * -(X + Y -1) * hue_c )).T # Shape = (60,3)

rgb_cycle = np.where(rgb_cycle<0, 0, rgb_cycle)
rgb_cycle
plt.scatter(X, Y, s = 15, c = rgb_cycle)
plt.colorbar()
# plt.show()

# rgb_cycle.min()

# %%
c = .92
rgb_cycle = np.vstack((            
    (Y) * c, 
    (-X + 1) * c  , 
    (- X + Y + 2) * 0 + .8)).T 
rgb_cycle = np.roll(rgb_cycle, 0, axis = 1)
# rgb_cycle = np.where(rgb_cycle<0, 0, rgb_cycle)
rgb_cycle
plt.scatter(X, Y, s = 40, c = rgb_cycle)
# plt.show()
rgb_cycle
# rgb_cycle.min()
# Out:
# array([[0.    , 0.92  , 0.8   ],
#        [0.    , 0.9016, 0.8   ],
#        [0.    , 0.8832, 0.8   ],
#        ...,
#        [0.92  , 0.0368, 0.8   ],
#        [0.92  , 0.0184, 0.8   ],
#        [0.92  , 0.    , 0.8   ]])

# %%
plt.scatter(X, Y, c = -(X + Y -1))
plt.colorbar()
