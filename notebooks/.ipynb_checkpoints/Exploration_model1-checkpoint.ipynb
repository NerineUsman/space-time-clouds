# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import cm
from cmcrameri import cm as  cmc
import matplotlib as mpl
import pandas as pd
import xarray as xr
import sys
sys.path.insert(0, '../lib')
sys.path.insert(0, '../src')

import ml_estimation as ml
import model1_plots as mp
import model1 as mod1
from scipy.stats import norm, beta
from statsmodels.base.model import GenericLikelihoodModel
import palettable as pal

# %%
# read data
# explorative
# 0. overview
ds_c = xr.open_dataset('../mod/model1/expl_hist_clouds.nc')

# 1. cs -> cs

# 2. c -> cs
ds_local = xr.open_dataset('../mod/model1/expl_local_param.nc')

# 3. cs -> c
ds_cs_c = xr.open_dataset('../mod/model1/expl_hist_cs_to_c.nc')

# 4. c -> c
df = pd.read_csv('../mod/model1/expl_example_bin_data.csv')
df_bin_fit = pd.read_csv('../mod/model1/expl_examble_bin_fit.csv')
# ds_local local param 

# global model1
df_glob_c_to_c_cod = pd.read_csv('../mod/model1/glob_c_to_c_cod.csv')
ds_theta = xr.open_dataset('../mod/model1/glob_theta.nc')

# %%
df
# Out:
#        Unnamed: 0  Unnamed: 0.1           h_t       d_t   ct  cloud  \
# 0            4406          4406    898.214478  0.113961  2.0  cloud
# 1           16538         16538    983.671570 -0.126211  2.0  cloud
# 2           23103         23103    996.184875 -0.107007  2.0  cloud
# 3           25417         25417    962.612488  0.139769  2.0  cloud
# 4           26111         26111    933.923340  0.107403  2.0  cloud
# ...           ...           ...           ...       ...  ...    ...
# 40350       18012         18012  12070.500977  2.951011  7.0  cloud
# 40351       18040         18040  11878.833008  3.016483  7.0  cloud
# 40352       18213         18213  11945.368164  2.851492  7.0  cloud
# 40353       18716         18716  11976.499023  3.036372  7.0  cloud
# 40354       19328         19328  11897.755859  2.930764  7.0  cloud
#
#            h_t_next  d_t_next  ct_next cloud_next           dh        dd  \
# 0        664.428467  0.655677      2.0      cloud  -233.786011  0.541716
# 1       1066.076538  1.390406      5.0      cloud    82.404968  1.516618
# 2       1887.684937  1.612455      5.0      cloud   891.500061  1.719461
# 3       4033.267090  0.509940      3.0      cloud  3070.654602  0.370172
# 4       1275.446289 -0.013675      2.0      cloud   341.522949 -0.121078
# ...             ...       ...      ...        ...          ...       ...
# 40350  12011.596680  2.138836      7.0      cloud   -58.904297 -0.812176
# 40351  11260.185547  2.493063      7.0      cloud  -618.647461 -0.523420
# 40352  10672.973633  3.796557     10.0      cloud -1272.394531  0.945065
# 40353  13200.975586  2.386468      7.0      cloud  1224.476562 -0.649904
# 40354  11848.923828  3.297898     10.0      cloud   -48.832031  0.367133
#
#        bincenter_h  bincenter_d
# 0           1000.0            0
# 1           1000.0            0
# 2           1000.0            0
# 3           1000.0            0
# 4           1000.0            0
# ...            ...          ...
# 40350      12000.0            3
# 40351      12000.0            3
# 40352      12000.0            3
# 40353      12000.0            3
# 40354      12000.0            3
#
# [40355 rows x 14 columns]

# %% [markdown]
# ## 0. Cloud distribution

# %%
from palettable.cubehelix import Cubehelix
palette = Cubehelix.make(start=1, rotation=2, n=16)

dedges, hedges, freq = ds_c.dedges.data, ds_c.hedges.data, ds_c.freq.data
fig, ax = mp.plotCloudHist_f(dedges, hedges, freq,
                          title = f'Cloud distribution n = {freq.sum().sum():.2e}',
                          density = True,
#                             cmap = pal.cubehelix.perceptual_rainbow_16.mpl_colormap,
                            cmap = cmc.batlow,
                            )
fig.savefig('../fig/model1/expl_cloud_distr.png')

# .colorbrewer.sequential import Blues_8
# ax.imshow(data, cmap=Blues_8.mpl_colormap)

# %% [markdown]
# # 1. Clear sky to Clear sky

# %%
# no exploration needed
ds_local.p_cscs
# Out:
# 0.7308294268298162

# %% [markdown]
# # 2. Cloud to clear sky

# %%
dh = ds_local.dh
dd = ds_local.dd
mu_h = ds_local.mu_h # m
mu_d = ds_local.mu_d
n_h = len(mu_h)
n_d = len(mu_d)

ds_local.p
# Out:
# <xarray.DataArray 'p' (mu_h: 44, mu_d: 17)>
# array([[0.867962, 0.579497, 0.505814, ..., 0.789506, 0.796962, 0.826981],
#        [0.821578, 0.854324, 0.778933, ..., 0.675632, 0.848072, 0.664389],
#        [0.909009, 0.796543, 0.797802, ..., 0.68312 , 0.594551, 0.608723],
#        ...,
#        [0.804985, 0.789903, 0.796695, ..., 0.918243, 0.897829, 0.896849],
#        [0.71546 , 0.756434, 0.790718, ..., 0.948393, 0.937773, 1.      ],
#        [0.650395, 0.894472, 0.781464, ..., 0.949763, 1.      , 0.761359]])
# Coordinates:
#   * mu_h     (mu_h) float64 1e+03 1.3e+03 1.6e+03 ... 1.33e+04 1.36e+04 1.39e+04
#   * mu_d     (mu_d) float64 -1.0 -0.7 -0.4 -0.1 0.2 0.5 ... 2.6 2.9 3.2 3.5 3.8

# %%
n = 3
n_d = 10
ind = list(np.round(np.linspace(0, n_d, n)).astype(int))
ind
np.floor(2.9)
mu_h
# Out:
# <xarray.DataArray 'mu_h' (mu_h: 44)>
# array([ 1000.,  1300.,  1600.,  1900.,  2200.,  2500.,  2800.,  3100.,  3400.,
#         3700.,  4000.,  4300.,  4600.,  4900.,  5200.,  5500.,  5800.,  6100.,
#         6400.,  6700.,  7000.,  7300.,  7600.,  7900.,  8200.,  8500.,  8800.,
#         9100.,  9400.,  9700., 10000., 10300., 10600., 10900., 11200., 11500.,
#        11800., 12100., 12400., 12700., 13000., 13300., 13600., 13900.])
# Coordinates:
#   * mu_h     (mu_h) float64 1e+03 1.3e+03 1.6e+03 ... 1.33e+04 1.36e+04 1.39e+04

# %%
fig, ax = mp.plotLocalParam(ds_local.n_bin, logscale = True)
fig.savefig('../fig/model1/expl_local_n_bin.png')

fig, ax = mp.plotLocalParam(ds_local.n, logscale = True)
fig.savefig('../fig/model1/expl_local_n.png')

fig, ax = mp.plotLocalParam(ds_local.p_cs, logscale = False, vmax = .2)
fig.savefig('../fig/model1/expl_local_p_cs.png')

# %% [markdown]
# # 3. Clear sky to Cloud

# %%
fig, ax = mp.plotCloudHist_f(ds_cs_c.dedges.data, ds_cs_c.hedges.data, ds_cs_c.freq.data,
                          title = f'Cloud distribution after clear sky, n = {ds_cs_c.freq.data.sum().sum():.2e}',
                         density = True)
theta = ds_theta.theta3
mp.plotCTHBeta(ax[0], *theta[0:2])
mp.plotCTHBetaMix(ax[0], *theta[2:7].data)
mp.plotCODNormal(ax[1], *theta[7:9])

ax[0].set_ylim([0,1.5])
fig.savefig('../fig/model1/expl_cs_cloud_distr.png')
theta
# Out:
# <xarray.DataArray 'theta3' (cs_to_c: 11)>
# array([ 0.354359,  1.815221,  0.813067, 25.047808,  1.825146,  1.435239,
#         0.798619,  0.749848,  0.73024 ,  1.      ,  1.      ])
# Dimensions without coordinates: cs_to_c
# Attributes:
#     var_names:  ['alpha', 'beta', 'alpha1', 'beta1', 'alpha2', 'beta2', 'p', ...

# %% [markdown]
# # 4. Cloud to Cloud

# %%
hlim = mp.hlim
dlim = mp.dlim

def plot_distribution_next_cloud(df, 
                                 title = None, 
                                 nbins = 50, 
                                 mixture = False,
                                 ML = True,
                                 **kwargs):
    # histograms
    freq, dedges, hedges = np.histogram2d(df.d_t_next, df.h_t_next, bins = nbins, **kwargs)
    fig, ax = mp.plotCloudHist_f(dedges, hedges, freq, density = True)
    return fig, ax


for idx, (h,d) in df_bin_fit[['bincenter_h', 'bincenter_d']].iterrows():
    df_bin = df.loc[(df.bincenter_h == h) & (df.bincenter_d == d)]
    param = df_bin_fit.loc[(df_bin_fit.bincenter_h == h) & (df_bin_fit.bincenter_d == d)]
    print(h,d)
    
    fig , ax = plot_distribution_next_cloud(df_bin, ML = False, density = True) # histograms cth, cod, joint

    # bin centers
    ax[0].axvline(h*1e-3, color = 'r', label = 'bin center')
    ax[1].axvline(d, color = 'r', label = 'bin center')
    ax[2].plot(d, h*1e-3,'ro', label = 'bin center')

    # fits
    # cod
    D = np.linspace(-1.5, 5, 50)
    H = np.linspace(0, 15e3, 50)
    H_norm = ml.CTHtoUnitInt(H)

    h_beta_fit = beta(param.alpha, param.beta).pdf(H_norm)
    p = param.p.values[0] 
    
    mp.plotCTHBeta(ax[0], param.alpha, param.beta)
    mp.plotCTHBetaMix(ax[0], param.alpha1, param.beta1, param.alpha2, param.beta2, param.p.values[0])
    mp.plotCODNormal(ax[1], param.mu, param.sigma)
    
    fig.savefig(f'../fig/model1/expl_bins{idx}.png')
# Out:
# 1000.0 0.0
# 6000.0 0.0
# 9000.0 0.0
# 12000.0 0.0
# 1000.0 1.0
# 6000.0 1.0
# C:\Users\nerin\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:881: RuntimeWarning: invalid value encountered in greater
#   cond = logical_and(cond, (asarray(arg) > 0))
# C:\Users\nerin\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:881: RuntimeWarning: invalid value encountered in greater
#   cond = logical_and(cond, (asarray(arg) > 0))
# 9000.0 1.0
# 12000.0 1.0
# 1000.0 2.0
# 6000.0 2.0
# 9000.0 2.0
# 12000.0 2.0
# 1000.0 3.0
# 6000.0 3.0
# 9000.0 3.0
# 12000.0 3.0

# %% [markdown]
# ## local behaviour parameters

# %% [markdown]
# ## cod

# %%
fig, ax = mp.plotLocalParam(ds_local.mu)
fig.savefig('../fig/model1/expl_local_mu.png')

fig, ax = mp.plotLocalParam(ds_local.sigma)
fig.savefig('../fig/model1/expl_local_sigma.png')

# %% [markdown]
# ## CTH

# %%
def meanBeta(alpha, beta):
    return alpha / (alpha + beta)

mu1 = meanBeta(ds_local.alpha1, ds_local.beta1).rename('mu1')
nu1 = (ds_local.alpha1 + ds_local.beta1).rename('nu1')
mu2 = meanBeta(ds_local.alpha2, ds_local.beta2).rename('mu2')
nu2 = (ds_local.alpha2 + ds_local.beta2).rename('nu2')

fig, ax = mp.plotLocalParam(mu1)
fig.savefig('../fig/model1/expl_local_mu1.png')
fig, ax = mp.plotLocalParam(nu1, logscale = True)
fig.savefig('../fig/model1/expl_local_nu1.png')
fig, ax = mp.plotLocalParam(mu2)
fig.savefig('../fig/model1/expl_local_mu2.png')

nu2 = nu2.where(nu2 < 1e3)
fig, ax = mp.plotLocalParam(nu2, logscale = True, vmin = .1)
fig.savefig('../fig/model1/expl_local_nu2.png')
fig, ax = mp.plotLocalParam(ds_local.p)
fig.savefig('../fig/model1/expl_local_p.png')
# Out:
# C:\Users\nerin\anaconda3\lib\site-packages\matplotlib\colors.py:1171: RuntimeWarning: invalid value encountered in less_equal
#   mask |= resdat <= 0

# %%
# Out:
# Text(0.5, 0.98, 'Estimators of time distribution COD')
# C:\Users\nerin\anaconda3\lib\site-packages\matplotlib\colors.py:1171: RuntimeWarning: invalid value encountered in less_equal
#   mask |= resdat <= 0

# %% [markdown]
# ## clear sky to cloud

# %% [markdown]
# ## cloud to clear sky
